# %%
# the cards that are highlighted have the following class (in hand)
# class = card zoomable highlight handy
# the cards in hand that are not highlighted are as follows:
# class = card zoomable handy
# cards on board that are not highlighted
# card zoomable mappy
# cards on board controlled by opponent
# card zoomable mappy opponent-controlled
# cards on board you control that are highlighted
# card zoomable highlight mappy
# choice of taking an action (e.g. attacking, discarding a card, summoning a card, etc.)
# action-choice
# this shows up when attacking an enemy, 
# class= "chooseable-space-overlay" style="background-color: rgba(153, 204, 102, 0.8); cursor: pointer;"
# the background color when an empty tile is highlighted 
# class="space-placeholder" style="background-color: rgba(153, 204, 102, 0.8); cursor: pointer;
# the background color when a tile is not highlighted
# style="background-color: rgba(0, 0, 0, 0); cursor: default;
# the buttons on the left side, go to next phase, etc.
# button class="control-panel-content-actions-action"
# empty spaces 
# class="space-placeholder-container"
# cards that opponent controls when you can force them
# card zoomable highlight mappy opponent-controlled

# %%
# !pip install webdriver_manager

# %%
from selenium import webdriver
import time
from webdriver_manager.chrome import ChromeDriverManager
import re
import pandas as pd
import numpy as np
np.__version__
# Out:
# '1.19.5'

# %%
df = pd.read_excel('../sw_alt_password.xlsx')

# %%
password = df['password'][1]
email = df['Email'][1]

# %%
factions = ['Breakers', 'Cave Goblins', 'Cloaks', 'Crimson Order', 'Eternal Council', 'Fallen Kingdom'
           , 'Fungal Dwarves', 'High Elves', 'Mountain Vargath', 'Obsidian Dwarves',
           'Phoenix Elves', 'Polar Dwarves', 'Sand Goblins', 'Savanna Elves',
           'Shadow Elves', 'Skyspear Avians', 'Swamp Orcs', 'Tundra Orcs',
           'Vanguards', 'Wayfarers']
player_faction = 'Tundra Orcs'
faction_index = factions.index(player_faction)
# only needs to be set for singleplayer
opposing_faction = 'Phoenix Elves'
opposing_index = factions.index(opposing_faction)

# %%
def start_game(singleplayer, faction_index, opposing_index, email, password, driver):
    url = 'https://www.plaidhatgames.com/accounts/login/?next=/redirect-swo'
    driver.get(url)



    time.sleep(5)
    login = driver.find_element_by_id('id_login')
    login.click()
    login.send_keys(email)
    time.sleep(.5)
    pw = driver.find_element_by_id('id_password')
    pw.click()
    pw.send_keys(password)
    time.sleep(.05)
    button = driver.find_element_by_class_name('primaryAction')
    button.click()
    time.sleep(15)
    buttons = driver.find_elements_by_class_name('menu-button-text-container')
    if singleplayer==True:
        buttons[1].click()
        time.sleep(3)
        settings = driver.find_element_by_class_name('settings-button-left')
        settings.click()
        time.sleep(1)
        autodismiss_events = driver.find_element_by_id('autodismiss_events')
        autodismiss_events.click()
        time.sleep(.05)
        attack_friendly = driver.find_element_by_id('attack_friendly')
        attack_friendly.click()
        time.sleep(.05)
        back_button = driver.find_element_by_class_name('full-overlay-back-button-img')
        back_button.click()
        time.sleep(.5)
        buttons = driver.find_elements_by_class_name('menu-button-text-container')
        buttons[3].click()
        time.sleep(3)
        buttons = driver.find_elements_by_class_name('use-deck-button')
        buttons[faction_index].click()
        time.sleep(1)
        buttons = driver.find_elements_by_class_name('use-deck-button')
        buttons[opposing_index].click()
    else:
        buttons[0].click()

# %%
# function that determines whether it's your turn
def is_turn(driver):
    time.sleep(.5)
    try:
        driver.find_element_by_class_name('control-panel-content-actions-action')
        return True
    except:
        return False

# %%
# driver = webdriver.Chrome(executable_path=r"C:\Users\steve\Downloads\chromedriver-win64\chromedriver-win64\chromedriver.exe")
driver = webdriver.Chrome(ChromeDriverManager().install())
start_game(singleplayer=True, faction_index=factions.index('Tundra Orcs'), opposing_index=factions.index('Phoenix Elves'),
          email=email, password=password, driver=driver)
print(is_turn(driver))
# Out:
# False

# %%
# driver.page_source

# %%
driver.find_element_by_id('map-space-0-0').get_attribute('outerHTML')
# Out:
# '<div class="table-card-pile table-map-space" id="map-space-0-0" style="position: absolute; width: 85.9692px; height: 60.6942px; top: 0px; left: 0px;"><div class="space-placeholder-container"><img src="data:image/png;base64,..." class="space-placeholder" alt="empty" style="background-color: rgba(0, 0, 0, 0); cursor: default; transform: none;"></div></div>'

# %%
# returns outer html for each space on the map
all_spaces = []
for col in range(6):
    single_col_spaces = []
    for row in range(8):
        space_html = driver.find_element_by_id(f'map-space-{col}-{row}').get_attribute('outerHTML')
        print(space_html)
        print('space-placeholder' in space_html)
        if 'space-placeholder' in space_html:
            friendly = 0
            occupied = False
        elif 'opponent' in space_html:
            print('enemy')
            friendly = -1
            occupied = True
        else:
            print('friendly')
            friendly = 1
            occupied = True
            
        # card-name
        if 'card-name' in space_html:
            html_card_name = re.findall('alt=[^<]+><div class="card-name">',space_html)
            regex_card_name = re.compile('{}(.*){}'.format(re.escape('alt='), re.escape('><div class="card-name">')))
            card_name = regex_card_name.findall(html_card_name[0])
            card_name = card_name[0]
            print(card_name)
        else:
            card_name = ''
            
        # card-strength
        if 'card-strength' in space_html:
            html_card_strength = re.findall('<div class="card-strength">[^<]+</div>',space_html)
            regex_card_strength = re.compile('{}(.*){}'.format(re.escape('<div class="card-strength">'), re.escape('</div>')))
            card_strength = regex_card_strength.findall(html_card_strength[0])
            card_strength = card_strength[0]
            print(card_strength)
        else:
            card_strength=0
            
        # card-life
        if 'card-life' in space_html:
            html_card_life = re.findall('<div class="card-life[^<]+</div>',space_html)
            regex_card_life = re.compile('{}(.*){}'.format(re.escape('>'), re.escape('</div>')))
            card_life = regex_card_life.findall(html_card_life[0])
            card_life = card_life[0]
            print(card_life)
        else:
            card_life=0
        # boost
        if 'boost' in space_html:
            html_card_boost = re.findall('<div class="boost">[^<]+</div>',space_html)
            regex_card_boost = re.compile('{}(.*){}'.format(re.escape('<div class="boost">'), re.escape('</div>')))
            boost = regex_card_boost.findall(html_card_boost[0])
            boost = boost[0]
            print(boost)
        else:
            boost=0
        # card-abilities-ability
        if 'card-abilities-ability' in space_html:
            html_card_abilities = re.findall('<div class="card-abilities-ability">[^<]+</div>',space_html)
            regex_card_abilities = re.compile('{}(.*){}'.format(re.escape('<div class="card-abilities-ability">'), re.escape('</div>')))
            card_abilities = [regex_card_abilities.findall(html_card_abilities[i])[0] for i in range(len(html_card_abilities))]
            print(card_abilities)
        else:
            card_abilities = ['']
        # append to the column list
        single_col_spaces.append([empty, friendly, card_name, card_strength, card_life, boost, card_abilities, row, col])
        
    # append to columns to all_spaces so it is a 2 dimensional list (can maybe perform convolutions?)
    all_spaces.append(single_col_spaces)
            
all_spaces
# Out:
# <div class="table-card-pile table-map-space" id="map-space-0-0" style="position: absolute; width: 85.9692px; height: 60.6942px; top: 0px; left: 0px;"><div class="space-placeholder-container"><img src="data:image/png;base64,..." class="space-placeholder" alt="empty" style="background-color: rgba(0, 0, 0, 0); cursor: default; transform: none;"></div></div>
# True
# <div class="table-card-pile table-map-space" id="map-space-0-1" style="position: absolute; width: 85.9692px; height: 60.6942px; top: 61.3012px; left: 0px;"><div class="space-placeholder-container"><img src="data:image/png;base64,..." class="space-placeholder" alt="empty" style="background-color: rgba(0, 0, 0, 0); cursor: default; transform: none;"></div></div>
# True
# <div class="table-card-pile table-map-space" id="map-space-0-2" style="position: absolute; width: 85.9692px; height: 60.6942px; top: 122.602px; left: 0px;"><div class="space-placeholder-container"><img src="data:image/png;base64,..." class="space-placeholder" alt="empty" style="background-color: rgba(0, 0, 0, 0); cursor: default; transform: none;"></div></div>
# True
# <div class="table-card-pile table-map-space" id="map-space-0-3" style="position: absolute; width: 85.9692px; height: 60.6942px; top: 183.904px; left: 0px;"><div class="space-placeholder-container"><img src="data:image/png;base64,..." class="space-placeholder" alt="empty" style="background-color: rgba(0, 0, 0, 0); cursor: default; transform: none;"></div></div>
# True
# <div class="table-card-pile table-map-space" id="map-space-0-4" style="position: absolute; width: 85.9692px; height: 60.6942px; top: 245.205px; left: 0px;"><div class="space-placeholder-container"><img src="data:image/png;base64,..." class="space-placeholder" alt="empty" style="background-color: rgba(0, 0, 0, 0); cursor: default; transform: none;"></div></div>
# True
# <div class="table-card-pile table-map-space" id="map-space-0-5" style="position: absolute; width: 85.9692px; height: 60.6942px; top: 306.506px; left: 0px;"><div class="space-placeholder-container"><img src="data:image/png;base64,..." class="space-placeholder" alt="empty" style="background-color: rgba(0, 0, 0, 0); cursor: default; transform: none;"></div></div>
# True
# <div class="table-card-pile table-map-space" id="map-space-0-6" style="position: absolute; width: 85.9692px; height: 60.6942px; top: 367.807px; left: 0px;"><div class="space-placeholder-container"><img src="data:image/png;base64,..." class="space-placeholder" alt="empty" style="background-color: rgba(0, 0, 0, 0); cursor: default; transform: none;"></div></div>
# True
# <div class="table-card-pile table-map-space" id="map-space-0-7" style="position: absolute; width: 85.9692px; height: 60.6942px; top: 429.108px; left: 0px;"><div class="space-placeholder-container"><img src="data:image/png;base64,..." class="space-placeholder" alt="empty" style="background-color: rgba(0, 0, 0, 0); cursor: default; transform: none;"></div></div>
# True
# <div class="table-card-pile table-map-space" id="map-space-1-0" style="position: absolute; width: 85.9692px; height: 60.6942px; top: 0px; left: 87.7745px;"><div class="space-placeholder-container"><img src="data:image/png;base64,..." class="space-placeholder" alt="empty" style="background-color: rgba(0, 0, 0, 0); cursor: default; transform: none;"></div></div>
# True
# <div class="table-card-pile table-map-space" id="map-space-1-1" style="position: absolute; width: 85.9692px; height: 60.6942px; top: 61.3012px; left: 87.7745px;"><div class="space-placeholder-container"><img src="data:image/png;base64,..." class="space-placeholder" alt="empty" style="background-color: rgba(0, 0, 0, 0); cursor: default; transform: none;"></div></div>
# True
# <div class="table-card-pile table-map-space" id="map-space-1-2" style="position: absolute; width: 85.9692px; height: 60.6942px; top: 122.602px; left: 87.7745px;"><div class="space-placeholder-container"><img src="data:image/png;base64,..." class="space-placeholder" alt="empty" style="background-color: rgba(0, 0, 0, 0); cursor: default; transform: none;"></div></div>
# True
# <div class="table-card-pile table-map-space" id="map-space-1-3" style="position: absolute; width: 85.9692px; height: 60.6942px; top: 183.904px; left: 87.7745px;"><div class="space-placeholder-container"><img src="data:image/png;base64,..." class="space-placeholder" alt="empty" style="background-color: rgba(0, 0, 0, 0); cursor: default; transform: none;"></div></div>
# True
# <div class="table-card-pile table-map-space" id="map-space-1-4" style="position: absolute; width: 85.9692px; height: 60.6942px; top: 245.205px; left: 87.7745px;"><div class="card zoomable mappy opponent-controlled" id="card-b689bcb2-a6de-48d7-8598-727b5aae0a4d" style="opacity: 1;"><img class="card-image" src="/static/media/PH3600-Cards-Fire_Archer-Small.5f4d8928.jpg" alt="Ember Archer"><div class="card-name">Archer</div><div class="card-strength">2</div><div class="card-life">2</div><div class="card-abilities"><div class="card-abilities-ability">Quick Shot</div></div><div class="map-card-effects"></div></div></div>
# False
# enemy
# "Ember Archer"
# 2
# 2
# ['Quick Shot']
# <div class="table-card-pile table-map-space" id="map-space-1-5" style="position: absolute; width: 85.9692px; height: 60.6942px; top: 306.506px; left: 87.7745px;"><div class="space-placeholder-container"><img src="data:image/png;base64,..." class="space-placeholder" alt="empty" style="background-color: rgba(0, 0, 0, 0); cursor: default; transform: none;"></div></div>
# True
# <div class="table-card-pile table-map-space" id="map-space-1-6" style="position: absolute; width: 85.9692px; height: 60.6942px; top: 367.807px; left: 87.7745px;"><div class="space-placeholder-container"><img src="data:image/png;base64,..." class="space-placeholder" alt="empty" style="background-color: rgba(0, 0, 0, 0); cursor: default; transform: none;"></div></div>
# True
# <div class="table-card-pile table-map-space" id="map-space-1-7" style="position: absolute; width: 85.9692px; height: 60.6942px; top: 429.108px; left: 87.7745px;"><div class="space-placeholder-container"><img src="data:image/png;base64,..." class="space-placeholder" alt="empty" style="background-color: rgba(0, 0, 0, 0); cursor: default; transform: none;"></div></div>
# True
# <div class="table-card-pile table-map-space" id="map-space-2-0" style="position: absolute; width: 85.9692px; height: 60.6942px; top: 0px; left: 175.549px;"><div class="card zoomable mappy opponent-controlled" id="card-c4522c67-497e-4c21-a26f-42add169b276" style="opacity: 1;"><img class="card-image" src="/static/media/PH3600-Cards-Maldaria-Small.85e74f41.jpg" alt="Queen Maldaria"><div class="card-name">Maldaria</div><div class="card-strength">4</div><div class="card-life">9</div><div class="card-abilities"><div class="card-abilities-ability">Protection</div><div class="card-abilities-ability">The Queen</div></div><div class="map-card-effects"></div></div></div>
# False
# enemy
# "Queen Maldaria"
# 4
# 9
# ['Protection', 'The Queen']
# <div class="table-card-pile table-map-space" id="map-space-2-1" style="position: absolute; width: 85.9692px; height: 60.6942px; top: 61.3012px; left: 175.549px;"><div class="space-placeholder-container"><img src="data:image/png;base64,..." class="space-placeholder" alt="empty" style="background-color: rgba(0, 0, 0, 0); cursor: default; transform: none;"></div></div>
# True
# <div class="table-card-pile table-map-space" id="map-space-2-2" style="position: absolute; width: 85.9692px; height: 60.6942px; top: 122.602px; left: 175.549px;"><div class="card zoomable mappy opponent-controlled" id="card-3b4c3f00-346f-42f8-81e3-24956823fea1" style="opacity: 1;"><img class="card-image" src="data:image/jpeg;base64,..." alt="gate"><div class="card-name">gate</div><div class="card-life nonunit">10</div><div class="map-card-effects"></div></div></div>
# False
# enemy
# "gate"
# 10
# <div class="table-card-pile table-map-space" id="map-space-2-3" style="position: absolute; width: 85.9692px; height: 60.6942px; top: 183.904px; left: 175.549px;"><div class="space-placeholder-container"><img src="data:image/png;base64,..." class="space-placeholder" alt="empty" style="background-color: rgba(0, 0, 0, 0); cursor: default; transform: none;"></div></div>
# True
# <div class="table-card-pile table-map-space" id="map-space-2-4" style="position: absolute; width: 85.9692px; height: 60.6942px; top: 245.205px; left: 175.549px;"><div class="card zoomable mappy opponent-controlled" id="card-59a5df9f-efb8-4526-920a-4126bc43e491" style="opacity: 1;"><img class="card-image" src="data:image/jpeg;base64,..." alt="Ember Beast"><div class="card-name">Beast</div><div class="card-strength">3</div><div class="card-life">3</div><div class="card-abilities"><div class="card-abilities-ability">Fire Born</div><div class="card-abilities-ability">Wildfire</div></div><div class="map-card-effects"></div></div></div>
# False
# enemy
# "Ember Beast"
# 3
# 3
# ['Fire Born', 'Wildfire']
# <div class="table-card-pile table-map-space" id="map-space-2-5" style="position: absolute; width: 85.9692px; height: 60.6942px; top: 306.506px; left: 175.549px;"><div class="card zoomable mappy" id="card-dbef98e3-1778-4343-b57c-0ac7bb18f779" style="opacity: 1;"><img class="card-image" src="/static/media/PH3600-Cards-Shaman-Small.97d9cc1d.jpg" alt="Frost Shaman"><div class="card-name">Shaman</div><div class="card-strength">3</div><div class="card-life wounded">1</div><div class="card-abilities"><div class="card-abilities-ability">Unwieldy</div></div><div class="map-card-effects"></div></div></div>
# False
# friendly
# "Frost Shaman"
# 3
# 1
# ['Unwieldy']
# <div class="table-card-pile table-map-space" id="map-space-2-6" style="position: absolute; width: 85.9692px; height: 60.6942px; top: 367.807px; left: 175.549px;"><div class="card zoomable mappy" id="card-0f8d146c-b78d-4d5f-913f-c88a7485a5e2" style="opacity: 1;"><img class="card-image" src="/static/media/PH3600-Cards-Grognack-Small.dd63677c.jpg" alt="Grognack"><div class="card-name">Grognack</div><div class="card-strength">4</div><div class="card-life">14</div><div class="card-abilities"><div class="card-abilities-ability">Restore</div><div class="card-abilities-ability">Influence</div></div><div class="map-card-effects"></div></div></div>
# False
# friendly
# "Grognack"
# 4
# 14
# ['Restore', 'Influence']
# <div class="table-card-pile table-map-space" id="map-space-2-7" style="position: absolute; width: 85.9692px; height: 60.6942px; top: 429.108px; left: 175.549px;"><div class="space-placeholder-container"><img src="data:image/png;base64,..." class="space-placeholder" alt="empty" style="background-color: rgba(0, 0, 0, 0); cursor: default; transform: none;"></div></div>
# True
# <div class="table-card-pile table-map-space" id="map-space-3-0" style="position: absolute; width: 85.9692px; height: 60.6942px; top: 0px; left: 263.324px;"><div class="space-placeholder-container"><img src="data:image/png;base64,..." class="space-placeholder" alt="empty" style="background-color: rgba(0, 0, 0, 0); cursor: default; transform: none;"></div></div>
# True
# <div class="table-card-pile table-map-space" id="map-space-3-1" style="position: absolute; width: 85.9692px; height: 60.6942px; top: 61.3012px; left: 263.324px;"><div class="space-placeholder-container"><img src="data:image/png;base64,..." class="space-placeholder" alt="empty" style="background-color: rgba(0, 0, 0, 0); cursor: default; transform: none;"></div></div>
# True
# <div class="table-card-pile table-map-space" id="map-space-3-2" style="position: absolute; width: 85.9692px; height: 60.6942px; top: 122.602px; left: 263.324px;"><div class="space-placeholder-container"><img src="data:image/png;base64,..." class="space-placeholder" alt="empty" style="background-color: rgba(0, 0, 0, 0); cursor: default; transform: none;"></div></div>
# True
# <div class="table-card-pile table-map-space" id="map-space-3-3" style="position: absolute; width: 85.9692px; height: 60.6942px; top: 183.904px; left: 263.324px;"><div class="card zoomable mappy opponent-controlled" id="card-9cee3532-e249-4092-a06d-ea50971699e7" style="opacity: 1;"><img class="card-image" src="/static/media/PH3600-Cards-Royal_Guard-Small.75658371.jpg" alt="Royal Guardian"><div class="card-name">Guardian</div><div class="card-strength">1</div><div class="card-life">4</div><div class="card-abilities"><div class="card-abilities-ability">Engage</div><div class="card-abilities-ability">Shove</div></div><div class="map-card-effects"></div></div></div>
# False
# enemy
# "Royal Guardian"
# 1
# 4
# ['Engage', 'Shove']
# <div class="table-card-pile table-map-space" id="map-space-3-4" style="position: absolute; width: 85.9692px; height: 60.6942px; top: 245.205px; left: 263.324px;"><div class="space-placeholder-container"><img src="data:image/png;base64,..." class="space-placeholder" alt="empty" style="background-color: rgba(0, 0, 0, 0); cursor: default; transform: none;"></div></div>
# True
# <div class="table-card-pile table-map-space" id="map-space-3-5" style="position: absolute; width: 85.9692px; height: 60.6942px; top: 306.506px; left: 263.324px;"><div class="card zoomable mappy" id="card-a955ee26-e7e0-4cf4-83f9-33caa8534187" style="opacity: 1;"><img class="card-image" src="data:image/jpeg;base64,..." alt="gate"><div class="card-name">gate</div><div class="card-life nonunit">10</div><div class="map-card-effects"></div></div></div>
# False
# friendly
# "gate"
# 10
# <div class="table-card-pile table-map-space" id="map-space-3-6" style="position: absolute; width: 85.9692px; height: 60.6942px; top: 367.807px; left: 263.324px;"><div class="space-placeholder-container"><img src="data:image/png;base64,..." class="space-placeholder" alt="empty" style="background-color: rgba(0, 0, 0, 0); cursor: default; transform: none;"></div></div>
# True
# <div class="table-card-pile table-map-space" id="map-space-3-7" style="position: absolute; width: 85.9692px; height: 60.6942px; top: 429.108px; left: 263.324px;"><div class="space-placeholder-container"><img src="data:image/png;base64,..." class="space-placeholder" alt="empty" style="background-color: rgba(0, 0, 0, 0); cursor: default; transform: none;"></div></div>
# True
# <div class="table-card-pile table-map-space" id="map-space-4-0" style="position: absolute; width: 85.9692px; height: 60.6942px; top: 0px; left: 351.098px;"><div class="space-placeholder-container"><img src="data:image/png;base64,..." class="space-placeholder" alt="empty" style="background-color: rgba(0, 0, 0, 0); cursor: default; transform: none;"></div></div>
# True
# <div class="table-card-pile table-map-space" id="map-space-4-1" style="position: absolute; width: 85.9692px; height: 60.6942px; top: 61.3012px; left: 351.098px;"><div class="space-placeholder-container"><img src="data:image/png;base64,..." class="space-placeholder" alt="empty" style="background-color: rgba(0, 0, 0, 0); cursor: default; transform: none;"></div></div>
# True
# <div class="table-card-pile table-map-space" id="map-space-4-2" style="position: absolute; width: 85.9692px; height: 60.6942px; top: 122.602px; left: 351.098px;"><div class="space-placeholder-container"><img src="data:image/png;base64,..." class="space-placeholder" alt="empty" style="background-color: rgba(0, 0, 0, 0); cursor: default; transform: none;"></div></div>
# True
# <div class="table-card-pile table-map-space" id="map-space-4-3" style="position: absolute; width: 85.9692px; height: 60.6942px; top: 183.904px; left: 351.098px;"><div class="space-placeholder-container"><img src="data:image/png;base64,..." class="space-placeholder" alt="empty" style="background-color: rgba(0, 0, 0, 0); cursor: default; transform: none;"></div></div>
# True
# <div class="table-card-pile table-map-space" id="map-space-4-4" style="position: absolute; width: 85.9692px; height: 60.6942px; top: 245.205px; left: 351.098px;"><div class="space-placeholder-container"><img src="data:image/png;base64,..." class="space-placeholder" alt="empty" style="background-color: rgba(0, 0, 0, 0); cursor: default; transform: none;"></div></div>
# True
# <div class="table-card-pile table-map-space" id="map-space-4-5" style="position: absolute; width: 85.9692px; height: 60.6942px; top: 306.506px; left: 351.098px;"><div class="space-placeholder-container"><img src="data:image/png;base64,..." class="space-placeholder" alt="empty" style="background-color: rgba(0, 0, 0, 0); cursor: default; transform: none;"></div></div>
# True
# <div class="table-card-pile table-map-space" id="map-space-4-6" style="position: absolute; width: 85.9692px; height: 60.6942px; top: 367.807px; left: 351.098px;"><div class="space-placeholder-container"><img src="data:image/png;base64,..." class="space-placeholder" alt="empty" style="background-color: rgba(0, 0, 0, 0); cursor: default; transform: none;"></div></div>
# True
# <div class="table-card-pile table-map-space" id="map-space-4-7" style="position: absolute; width: 85.9692px; height: 60.6942px; top: 429.108px; left: 351.098px;"><div class="space-placeholder-container"><img src="data:image/png;base64,..." class="space-placeholder" alt="empty" style="background-color: rgba(0, 0, 0, 0); cursor: default; transform: none;"></div></div>
# True
# <div class="table-card-pile table-map-space" id="map-space-5-0" style="position: absolute; width: 85.9692px; height: 60.6942px; top: 0px; left: 438.873px;"><div class="space-placeholder-container"><img src="data:image/png;base64,..." class="space-placeholder" alt="empty" style="background-color: rgba(0, 0, 0, 0); cursor: default; transform: none;"></div></div>
# True
# <div class="table-card-pile table-map-space" id="map-space-5-1" style="position: absolute; width: 85.9692px; height: 60.6942px; top: 61.3012px; left: 438.873px;"><div class="space-placeholder-container"><img src="data:image/png;base64,..." class="space-placeholder" alt="empty" style="background-color: rgba(0, 0, 0, 0); cursor: default; transform: none;"></div></div>
# True
# <div class="table-card-pile table-map-space" id="map-space-5-2" style="position: absolute; width: 85.9692px; height: 60.6942px; top: 122.602px; left: 438.873px;"><div class="space-placeholder-container"><img src="data:image/png;base64,..." class="space-placeholder" alt="empty" style="background-color: rgba(0, 0, 0, 0); cursor: default; transform: none;"></div></div>
# True
# <div class="table-card-pile table-map-space" id="map-space-5-3" style="position: absolute; width: 85.9692px; height: 60.6942px; top: 183.904px; left: 438.873px;"><div class="space-placeholder-container"><img src="data:image/png;base64,..." class="space-placeholder" alt="empty" style="background-color: rgba(0, 0, 0, 0); cursor: default; transform: none;"></div></div>
# True
# <div class="table-card-pile table-map-space" id="map-space-5-4" style="position: absolute; width: 85.9692px; height: 60.6942px; top: 245.205px; left: 438.873px;"><div class="space-placeholder-container"><img src="data:image/png;base64,..." class="space-placeholder" alt="empty" style="background-color: rgba(0, 0, 0, 0); cursor: default; transform: none;"></div></div>
# True
# <div class="table-card-pile table-map-space" id="map-space-5-5" style="position: absolute; width: 85.9692px; height: 60.6942px; top: 306.506px; left: 438.873px;"><div class="space-placeholder-container"><img src="data:image/png;base64,..." class="space-placeholder" alt="empty" style="background-color: rgba(0, 0, 0, 0); cursor: default; transform: none;"></div></div>
# True
# <div class="table-card-pile table-map-space" id="map-space-5-6" style="position: absolute; width: 85.9692px; height: 60.6942px; top: 367.807px; left: 438.873px;"><div class="space-placeholder-container"><img src="data:image/png;base64,..." class="space-placeholder" alt="empty" style="background-color: rgba(0, 0, 0, 0); cursor: default; transform: none;"></div></div>
# True
# <div class="table-card-pile table-map-space" id="map-space-5-7" style="position: absolute; width: 85.9692px; height: 60.6942px; top: 429.108px; left: 438.873px;"><div class="space-placeholder-container"><img src="data:image/png;base64,..." class="space-placeholder" alt="empty" style="background-color: rgba(0, 0, 0, 0); cursor: default; transform: none;"></div></div>
# True
# [[[True, 0, '', 0, 0, 0, [''], 0, 0],
#   [True, 0, '', 0, 0, 0, [''], 1, 0],
#   [True, 0, '', 0, 0, 0, [''], 2, 0],
#   [True, 0, '', 0, 0, 0, [''], 3, 0],
#   [True, 0, '', 0, 0, 0, [''], 4, 0],
#   [True, 0, '', 0, 0, 0, [''], 5, 0],
#   [True, 0, '', 0, 0, 0, [''], 6, 0],
#   [True, 0, '', 0, 0, 0, [''], 7, 0]],
#  [[True, 0, '', 0, 0, 0, [''], 0, 1],
#   [True, 0, '', 0, 0, 0, [''], 1, 1],
#   [True, 0, '', 0, 0, 0, [''], 2, 1],
#   [True, 0, '', 0, 0, 0, [''], 3, 1],
#   [False, -1, '"Ember Archer"', '2', '2', 0, ['Quick Shot'], 4, 1],
#   [True, 0, '', 0, 0, 0, [''], 5, 1],
#   [True, 0, '', 0, 0, 0, [''], 6, 1],
#   [True, 0, '', 0, 0, 0, [''], 7, 1]],
#  [[False,
#    -1,
#    '"Queen Maldaria"',
#    '4',
#    '9',
#    0,
#    ['Protection', 'The Queen'],
#    0,
#    2],
#   [True, 0, '', 0, 0, 0, [''], 1, 2],
#   [False, -1, '"gate"', 0, '10', 0, [''], 2, 2],
#   [True, 0, '', 0, 0, 0, [''], 3, 2],
#   [False, -1, '"Ember Beast"', '3', '3', 0, ['Fire Born', 'Wildfire'], 4, 2],
#   [False, 1, '"Frost Shaman"', '3', '1', 0, ['Unwieldy'], 5, 2],
#   [False, 1, '"Grognack"', '4', '14', 0, ['Restore', 'Influence'], 6, 2],
#   [True, 0, '', 0, 0, 0, [''], 7, 2]],
#  [[True, 0, '', 0, 0, 0, [''], 0, 3],
#   [True, 0, '', 0, 0, 0, [''], 1, 3],
#   [True, 0, '', 0, 0, 0, [''], 2, 3],
#   [False, -1, '"Royal Guardian"', '1', '4', 0, ['Engage', 'Shove'], 3, 3],
#   [True, 0, '', 0, 0, 0, [''], 4, 3],
#   [False, 1, '"gate"', 0, '10', 0, [''], 5, 3],
#   [True, 0, '', 0, 0, 0, [''], 6, 3],
#   [True, 0, '', 0, 0, 0, [''], 7, 3]],
#  [[True, 0, '', 0, 0, 0, [''], 0, 4],
#   [True, 0, '', 0, 0, 0, [''], 1, 4],
#   [True, 0, '', 0, 0, 0, [''], 2, 4],
#   [True, 0, '', 0, 0, 0, [''], 3, 4],
#   [True, 0, '', 0, 0, 0, [''], 4, 4],
#   [True, 0, '', 0, 0, 0, [''], 5, 4],
#   [True, 0, '', 0, 0, 0, [''], 6, 4],
#   [True, 0, '', 0, 0, 0, [''], 7, 4]],
#  [[True, 0, '', 0, 0, 0, [''], 0, 5],
#   [True, 0, '', 0, 0, 0, [''], 1, 5],
#   [True, 0, '', 0, 0, 0, [''], 2, 5],
#   [True, 0, '', 0, 0, 0, [''], 3, 5],
#   [True, 0, '', 0, 0, 0, [''], 4, 5],
#   [True, 0, '', 0, 0, 0, [''], 5, 5],
#   [True, 0, '', 0, 0, 0, [''], 6, 5],
#   [True, 0, '', 0, 0, 0, [''], 7, 5]]]

# %%
# observation, reward, done, and info?

# %%
# gets the current state of the board, cards in hand, discarded cards, active events, cards in deck, etc.
def get_board_state()
# Out:
#   Cell In[35], line 2
#     def get_board_state()
#                          ^
# SyntaxError: invalid syntax

# %%
# possible actions that can be taken at any given point
def get_available_actions()

# %%
# choose an action, evaluating them?? (need to refresh on reinforcement learning here)
def evaluate_actions()
