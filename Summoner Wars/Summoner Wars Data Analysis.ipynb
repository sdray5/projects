# %%
import pandas as pd

# %%
card_df = pd.read_csv('Summoner_Wars_Cards.csv')
card_df
# Out:
#      Unnamed: 0         Card Name  Card Classes   Event Phase  Active Event  \
# 0             0           Tacullu  ['Summoner']           NaN         False
# 1             1      Mind Control            []  Summon Phase         False
# 2             2          Deceiver    ['Common']           NaN         False
# 3             3        Mind Witch    ['Common']           NaN         False
# 4             4          Gulldune  ['Champion']           NaN         False
# ..          ...               ...           ...           ...           ...
# 235         235      Glory Caller    ['Common']           NaN         False
# 236         236  Slagborn Fighter    ['Common']           NaN         False
# 237         237     Battle Leader            []    Move Phase          True
# 238         238    Marshal Forces            []  Attack Phase         False
# 239         239   Ramming Advance            []    Move Phase          True
#
#                   Abilities  \
# ...
