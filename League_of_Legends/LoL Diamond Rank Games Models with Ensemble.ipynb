# %% [markdown]
# # Reading in the data

# %%
import pandas as pd
lol_games = pd.read_csv("high_diamond_ranked_10min.csv")
lol_games
# Out:
#           gameId  blueWins  blueWardsPlaced  blueWardsDestroyed  \
# 0     4519157822         0               28                   2
# 1     4523371949         0               12                   1
# 2     4521474530         0               15                   0
# 3     4524384067         0               43                   1
# 4     4436033771         0               75                   4
# ...          ...       ...              ...                 ...
# 9874  4527873286         1               17                   2
# 9875  4527797466         1               54                   0
# 9876  4527713716         0               23                   1
# 9877  4527628313         0               14                   4
# 9878  4523772935         1               18                   0
#
#       blueFirstBlood  blueKills  blueDeaths  blueAssists  blueEliteMonsters  \
# 0                  1          9           6           11                  0
# ...

# %%
lol_games = lol_games.drop('gameId', axis=1)
lol_games
# Out:
#       blueWins  blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  \
# 0            0               28                   2               1
# 1            0               12                   1               0
# 2            0               15                   0               0
# 3            0               43                   1               0
# 4            0               75                   4               0
# ...        ...              ...                 ...             ...
# 9874         1               17                   2               1
# 9875         1               54                   0               0
# 9876         0               23                   1               0
# 9877         0               14                   4               1
# 9878         1               18                   0               1
#
#       blueKills  blueDeaths  blueAssists  blueEliteMonsters  blueDragons  \
# 0             9           6           11                  0            0
# ...

# %%
#X = lol_games.drop(['blueWins', 'redGoldDiff', 'redExperienceDiff', 'redFirstBlood','blueGoldPerMin', 'redGoldPerMin', 'blueCSPerMin', 'redCSPerMin'], axis=1)
X = lol_games.drop('blueWins', axis=1)
y = lol_games['blueWins'].values
X
# Out:
#       blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  blueKills  \
# 0                  28                   2               1          9
# 1                  12                   1               0          5
# 2                  15                   0               0          7
# 3                  43                   1               0          4
# 4                  75                   4               0          6
# ...               ...                 ...             ...        ...
# 9874               17                   2               1          7
# 9875               54                   0               0          6
# 9876               23                   1               0          6
# 9877               14                   4               1          2
# 9878               18                   0               1          6
#
#       blueDeaths  blueAssists  blueEliteMonsters  blueDragons  blueHeralds  \
# ...

# %%
#Splitting the data into Training Set and Test Set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=0)
X_test
# Out:
#       blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  blueKills  \
# 3535               13                   1               1          5
# 7150               18                   7               1          7
# 9578               12                   1               0          6
# 6882               12                   3               0          3
# 3766               17                   2               1          5
# ...               ...                 ...             ...        ...
# 2515               20                   2               0          4
# 6556               16                   3               1          2
# 4110               10                   2               0          9
# 6198               87                   2               0          2
# 2615               78                   1               1          4
#
#       blueDeaths  blueAssists  blueEliteMonsters  blueDragons  blueHeralds  \
# ...

# %% [markdown]
# # Decision Tree

# %%
#Fitting Classifier to Training Set. Create a classifier object here and call it classifierObj
from sklearn.tree import DecisionTreeClassifier
classifierObj = DecisionTreeClassifier(criterion='entropy', random_state=0)
classifierObj.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
#Making predictions on the Test Set
decision_tree_pred = classifierObj.predict(X_test)

# %%
#Evaluating the predictions using a Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, decision_tree_pred)
cm
# Out:
# array([[984, 536],
#        [512, 932]], dtype=int64)

# %%
classifierObj.score(X_test,y_test)
# a single decision tree gets a score of 64.6%
# Out:
# 0.6464237516869096

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
classifierObj = RandomForestClassifier(n_estimators=500, criterion='entropy', max_depth=8, min_samples_leaf=20, random_state=0)
classifierObj.fit(X_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=8, min_samples_leaf=20,
#                        n_estimators=500, random_state=0)

# %%
#Making predictions on the Test Set
random_forest_pred = classifierObj.predict(X_test)

# %%
classifierObj.score(X_test,y_test)
# 72.3%
# Out:
# 0.7230094466936572

# %% [markdown]
# # KNN

# %%
#Normalizing the features
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train_normalized = sc_X.fit_transform(X_train)
X_test_normalized = sc_X.transform(X_test)

# %%
#Fitting Classifier to Training Set. Create a classifier object here and call it classifierObj
from sklearn.neighbors import KNeighborsClassifier
classifierObj = KNeighborsClassifier(n_neighbors=50, p=2, metric='minkowski')
classifierObj.fit(X_train_normalized, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=50)

# %%
#Making predictions on the Test Set
knn_pred = classifierObj.predict(X_test_normalized)

# %%
classifierObj.score(X_test_normalized,y_test)
# 71.5%
# Out:
# 0.7152496626180836

# %% [markdown]
# # Logistic Regression

# %%
#Fitting Logistic Regression to Training Set
from sklearn.linear_model import LogisticRegression
classifierObj = LogisticRegression(random_state=0)
classifierObj.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
#Making predictions on the Test Set
logistic_reg_pred = classifierObj.predict(X_test)

# %%
classifierObj.score(X_test,y_test)
# 72.1%
# Out:
# 0.7213225371120108

# %% [markdown]
# # Naive Bayes

# %%
#Fitting Classifier to Training Set. Create a classifier object here and call it classifierObj
from sklearn.naive_bayes import GaussianNB
classifierObj = GaussianNB()
classifierObj.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
#Making predictions on the Test Set
naive_bayes_pred = classifierObj.predict(X_test)

# %%
classifierObj.score(X_test,y_test)
# 71.9%
# Out:
# 0.7189608636977058

# %% [markdown]
# # SVM

# %%
#Fitting Classifier to Training Set. Create a classifier object here and call it classifierObj
# can use linear, poly, rbf, sigmoid,or precomputed kernels
from sklearn.svm import SVC
classifierObj = SVC(C=2, kernel='linear')
classifierObj.fit(X_train, y_train)
# Out:
# SVC(C=2, kernel='linear')

# %%
#Making predictions on the Test Set
svm_pred = classifierObj.predict(X_test)

# %%
classifierObj.score(X_test,y_test)
# 72%
# Out:
# 0.7223346828609987

# %% [markdown]
# # Ensemble

# %%
total = random_forest_pred + knn_pred + logistic_reg_pred + naive_bayes_pred + svm_pred
# sets all values to one or zero
for i in range(len(total)):
    if total[i] >= 3:
        total[i] = 1
    else:
        total[i] = 0
sum(total == y_test)/len(y_test)
# very similar to what we got before
# Out:
# 0.7192982456140351

# %%
data = {'Random Forest':  random_forest_pred,
        'KNN': knn_pred,
        'Logistic Regression': logistic_reg_pred,
        'Naive Bayes': naive_bayes_pred,
        'SVM': svm_pred
        }
predictions = pd.DataFrame (data)

# %%
predictions.corr()
# Out:
#                      Random Forest       KNN  Logistic Regression  \
# Random Forest             1.000000  0.827826             0.898788
# KNN                       0.827826  1.000000             0.772461
# Logistic Regression       0.898788  0.772461             1.000000
# Naive Bayes               0.895322  0.835233             0.837277
# SVM                       0.916232  0.804842             0.908197
#
#                      Naive Bayes       SVM
# Random Forest           0.895322  0.916232
# KNN                     0.835233  0.804842
# Logistic Regression     0.837277  0.908197
# Naive Bayes             1.000000  0.892608
# SVM                     0.892608  1.000000

# %%
sum(logistic_reg_pred == knn_pred)/len(y_test)
# Out:
# 0.886302294197031
