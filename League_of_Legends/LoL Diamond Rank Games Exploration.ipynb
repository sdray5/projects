# %%
import pandas as pd
lol_games = pd.read_csv("high_diamond_ranked_10min.csv")
lol_games
# Out:
#           gameId  blueWins  blueWardsPlaced  blueWardsDestroyed  \
# 0     4519157822         0               28                   2
# 1     4523371949         0               12                   1
# 2     4521474530         0               15                   0
# 3     4524384067         0               43                   1
# 4     4436033771         0               75                   4
# ...          ...       ...              ...                 ...
# 9874  4527873286         1               17                   2
# 9875  4527797466         1               54                   0
# 9876  4527713716         0               23                   1
# 9877  4527628313         0               14                   4
# 9878  4523772935         1               18                   0
#
#       blueFirstBlood  blueKills  blueDeaths  blueAssists  blueEliteMonsters  \
# 0                  1          9           6           11                  0
# ...

# %%
import numpy as np
lol_games.isnull().any()
# no missing data
# Out:
# gameId                          False
# blueWins                        False
# blueWardsPlaced                 False
# blueWardsDestroyed              False
# blueFirstBlood                  False
# blueKills                       False
# blueDeaths                      False
# blueAssists                     False
# blueEliteMonsters               False
# blueDragons                     False
# blueHeralds                     False
# blueTowersDestroyed             False
# blueTotalGold                   False
# blueAvgLevel                    False
# blueTotalExperience             False
# blueTotalMinionsKilled          False
# blueTotalJungleMinionsKilled    False
# blueGoldDiff                    False
# blueExperienceDiff              False
# blueCSPerMin                    False
# blueGoldPerMin                  False
# redWardsPlaced                  False
# redWardsDestroyed               False
# redFirstBlood                   False
# redKills                        False
# ...

# %%
lol_games = lol_games.drop('gameId', axis=1)
lol_games
# Out:
#       blueWins  blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  \
# 0            0               28                   2               1
# 1            0               12                   1               0
# 2            0               15                   0               0
# 3            0               43                   1               0
# 4            0               75                   4               0
# ...        ...              ...                 ...             ...
# 9874         1               17                   2               1
# 9875         1               54                   0               0
# 9876         0               23                   1               0
# 9877         0               14                   4               1
# 9878         1               18                   0               1
#
#       blueKills  blueDeaths  blueAssists  blueEliteMonsters  blueDragons  \
# 0             9           6           11                  0            0
# ...

# %%
from sklearn.preprocessing import StandardScaler
lol_games_standardized = pd.DataFrame(StandardScaler().fit_transform(lol_games), columns = lol_games.columns)
lol_games_standardized
# Out:
#       blueWins  blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  \
# 0    -0.998079         0.316996           -0.379275        0.990429
# 1    -0.998079        -0.570992           -0.839069       -1.009663
# 2    -0.998079        -0.404494           -1.298863       -1.009663
# 3    -0.998079         1.149484           -0.839069       -1.009663
# 4    -0.998079         2.925460            0.540312       -1.009663
# ...        ...              ...                 ...             ...
# 9874  1.001925        -0.293496           -0.379275        0.990429
# 9875  1.001925         1.759976           -1.298863       -1.009663
# 9876 -0.998079         0.039499           -0.839069       -1.009663
# 9877 -0.998079        -0.459994            0.540312        0.990429
# 9878  1.001925        -0.237997           -1.298863        0.990429
#
#       blueKills  blueDeaths  blueAssists  blueEliteMonsters  blueDragons  \
# 0      0.935301   -0.046926     1.071495          -0.879231    -0.753226
# ...

# %%
np.sum(abs(lol_games_standardized) > 3, axis=0)/len(lol_games_standardized)*100
# Out:
# blueWins                        0.000000
# blueWardsPlaced                 2.844417
# blueWardsDestroyed              1.153963
# blueFirstBlood                  0.000000
# blueKills                       0.506124
# blueDeaths                      0.657961
# blueAssists                     0.931268
# blueEliteMonsters               0.000000
# blueDragons                     0.000000
# blueHeralds                     0.000000
# blueTowersDestroyed             4.696832
# blueTotalGold                   0.546614
# blueAvgLevel                    0.698451
# blueTotalExperience             0.516247
# blueTotalMinionsKilled          0.313797
# blueTotalJungleMinionsKilled    0.404899
# blueGoldDiff                    0.475757
# blueExperienceDiff              0.455512
# blueCSPerMin                    0.313797
# blueGoldPerMin                  0.546614
# redWardsPlaced                  2.469886
# redWardsDestroyed               1.113473
# redFirstBlood                   0.000000
# ...

# %%
np.sum(abs(lol_games_standardized) > 5, axis=0)/len(lol_games_standardized)*100
# Out:
# blueWins                        0.000000
# blueWardsPlaced                 0.809799
# blueWardsDestroyed              0.688329
# blueFirstBlood                  0.000000
# blueKills                       0.010122
# blueDeaths                      0.010122
# blueAssists                     0.040490
# blueEliteMonsters               0.000000
# blueDragons                     0.000000
# blueHeralds                     0.000000
# blueTowersDestroyed             0.354287
# blueTotalGold                   0.000000
# blueAvgLevel                    0.040490
# blueTotalExperience             0.040490
# blueTotalMinionsKilled          0.010122
# blueTotalJungleMinionsKilled    0.020245
# blueGoldDiff                    0.000000
# blueExperienceDiff              0.000000
# blueCSPerMin                    0.010122
# blueGoldPerMin                  0.000000
# redWardsPlaced                  0.830044
# redWardsDestroyed               0.668084
# redFirstBlood                   0.000000
# ...

# %%
np.sum(abs(lol_games_standardized) > 5, axis=0)
# Out:
# blueWins                         0
# blueWardsPlaced                 80
# blueWardsDestroyed              68
# blueFirstBlood                   0
# blueKills                        1
# blueDeaths                       1
# blueAssists                      4
# blueEliteMonsters                0
# blueDragons                      0
# blueHeralds                      0
# blueTowersDestroyed             35
# blueTotalGold                    0
# blueAvgLevel                     4
# blueTotalExperience              4
# blueTotalMinionsKilled           1
# blueTotalJungleMinionsKilled     2
# blueGoldDiff                     0
# blueExperienceDiff               0
# blueCSPerMin                     1
# blueGoldPerMin                   0
# redWardsPlaced                  82
# redWardsDestroyed               66
# redFirstBlood                    0
# redKills                         1
# redDeaths                        1
# redAssists                       1
# redEliteMonsters                 0
# ...

# %%
import matplotlib.pyplot as plt
plt.boxplot(lol_games_standardized['blueWardsPlaced'])  
plt.show()

# %%
plt.boxplot(lol_games_standardized['blueWardsDestroyed'])  
plt.show()

# %%
plt.boxplot(lol_games_standardized['blueTowersDestroyed'])  
plt.show()

# %%
min(lol_games_standardized['blueWardsPlaced']), min(lol_games_standardized['blueWardsDestroyed']), min(lol_games_standardized['blueTowersDestroyed'])
# Out:
# (-0.9594868745249477, -1.2988625963224838, -0.21043903299552771)

# %%
min(lol_games_standardized['redWardsPlaced']), min(lol_games_standardized['redWardsDestroyed']), min(lol_games_standardized['redTowersDestroyed'])
# Out:
# (-0.886839800968657, -1.273542761899331, -0.19835287513965713)

# %%
max(lol_games_standardized['blueWardsPlaced']), max(lol_games_standardized['blueWardsDestroyed']), max(lol_games_standardized['blueTowersDestroyed'])
# Out:
# (12.637827118547461, 11.115568080743667, 16.159066533640836)

# %%
max(lol_games_standardized['redWardsPlaced']), max(lol_games_standardized['redWardsDestroyed']), max(lol_games_standardized['redTowersDestroyed'])
# Out:
# (13.742158562148788, 9.950600226550739, 9.022955611941155)

# %%
# blueWardsPlaced, blueWardsDestroyed, blueTowersDestroyed, redWardsPlaced, redWardsDestroyed, and redTowersDestroyed
# are all right skewed and >1% of data in each of those columns have a z-score greater than 3

# %%
len(lol_games_standardized)
# Out:
# 9879
